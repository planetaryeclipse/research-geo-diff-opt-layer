# %% [markdown]
# Train the network with the non-product formulation of the GCBF.

# %%
import torch
import torch.nn as nn
import tqdm
import pathlib

import numpy as np
import matplotlib.pyplot as plt

from diff_mfld_optim.geometry.connection import Connection
from diff_mfld_optim.geometry.metric import MetricField, RnMetricField
from diff_mfld_optim.optim.constrained import (
    ConstrainedSolverCfg,
    ConstrainedSolverMethod,
    ConstrainedSolverResult,
)
from diff_mfld_optim.optim.subsolver import SolverCfg, SubsolverMethod

from enum import Enum
from dataclasses import dataclass
from datetime import datetime
from torch.utils.data import DataLoader

# import multiprocessing
# from multiprocessing.pool import Pool

# import pathos.multiprocessing
# from pathos.multiprocessing import ProcessingPool
from multiprocessing.dummy import Pool
from pathos.multiprocessing import ProcessingPool

from controller import Controller
from diff_mfld_optim.optim.subsolver import OptimFunc, FuncArgs
from diff_mfld_optim.mfld_util import MfldCfg, dist_squared_map

from geo_diff_opt_layer_ml.util.nominal_mpc_dataloader import (
    EPISODES_TRAIN_DIR,
    EPISODES_VALID_DIR,
    MPC_TRAIN_DIR,
    MPC_VALID_DIR,
    KO_TRAIN_DIR,
    KO_VALID_DIR,
    MPCEpisode,
    MPCEpisodeDataset,
)

from gcbf import cbf_ko

from euclid_cbf import batched_cbf_ko_coeffs

from diff_mfld_optim.layers.diff_opt_layer import DiffMfldOptimLayer

# %%
import sys
sys._is_gil_enabled()
# Out:
# False

# %%
# device = torch.device(
#     "cuda:0"
#     if torch.cuda.is_available()
#     else "mps" if torch.backends.mps.is_available() else "cpu"
# )
device = torch.device("cpu")
device
# Out:
# device(type='cpu')

# %%
mpc_train_dataset = MPCEpisodeDataset(EPISODES_TRAIN_DIR, MPC_TRAIN_DIR, KO_TRAIN_DIR, device=device)
mpc_valid_dataset = MPCEpisodeDataset(EPISODES_VALID_DIR, MPC_VALID_DIR, KO_VALID_DIR, device=device)
# Out:
# /home/samuel/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/geo_diff_opt_layer_ml/util/nominal_mpc_dataloader.py:131: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   torch.tensor(mpc_f["p_hist"], dtype=torch.float32, device=device),

# %%
# setup the geometric optimization problem


def gcbf_f(u: torch.Tensor, mfld_cfg: MfldCfg, u_nom: torch.Tensor, *_args):
    return 0.5 * dist_squared_map(u, u_nom, mfld_cfg)


def gcbf_g(
    u: torch.Tensor,
    _mfld_cfg: MfldCfg,
    # unused but the cost and constraint functions must accept the same number
    # of arguments as we're passing extra data during the forward pass which
    # iss used to compute the values and differentials of the cost and constraints
    _u_nom: torch.Tensor,
    p: torch.Tensor,
    ko: torch.Tensor,
    k1: torch.Tensor,
    k2: torch.Tensor,
):
    return cbf_ko(p, u, ko, k1, k2)


metric_field = RnMetricField(2)  # Euclidean for now
conn = metric_field.christoffels()  # Levi-Citivta connection
mfld_cfg = MfldCfg(metric_field, conn)

subsolver_cfg = SolverCfg()

print(subsolver_cfg)


constr_solv_cfg = ConstrainedSolverCfg(
    SubsolverMethod.RIEM_GRAD_DESCENT,
    subsolver_cfg,  # only one available (for now)
)

geo_constr_layer = DiffMfldOptimLayer(
    gcbf_f,
    [gcbf_g],
    [],
    mfld_cfg,
    constr_solv_cfg,
    ConstrainedSolverMethod.RALM,  # only one available (for now)
)
geo_constr_layer
# Out:
# SolverCfg(conv_eps=1e-06, damp=0.6, damp_growth=0.95, damp_clip=(1e-06, 2.0), max_iters=1000)
# DiffMfldOptimLayer()

# %%
def _filter_batch(p, x_traj, y_traj, u, ko):
    # filters the batch so that we don't train on any cases where the current
    # state of the system is inside the keep-out region (as we generated them
    # randomly and cannot do this directly inside the dataloader)

    x, y = p[:, 0], p[:, 1]
    ko_x, ko_y, ko_rad = ko[:, 0], ko[:, 1], ko[:, 6]

    # determines which bached states are outside thet keep-out radius
    dist_sqr = (x - ko_x) ** 2 + (y - ko_y) ** 2
    rad_sqr = ko_rad**2

    outside_ko_idxs = dist_sqr >= rad_sqr

    # now filter teh batch based on the valid idxs
    return (
        p[outside_ko_idxs, :],
        x_traj[outside_ko_idxs],
        y_traj[outside_ko_idxs],
        u[outside_ko_idxs, :],
        ko[outside_ko_idxs, :],
    )


def _h_batch(p, x_traj, y_traj, u, ko):
    x, y = p[:, 0], p[:, 1]
    ko_x, ko_y, ko_rad = ko[:, 0], ko[:, 1], ko[:, 6]

    return torch.sqrt((ko_x - x) ** 2 + (ko_y - y) ** 2) - ko_rad


def _h_grad(p, x_traj, y_traj, u, ko):
    x, y = p[:, 0], p[:, 1]
    ko_x, ko_y, ko_rad = ko[:, 0], ko[:, 1], ko[:, 6]

    x_diff = -2 * (ko_x - x) / torch.sqrt((ko_x - x) ** 2 + (ko_y - y) ** 2)
    y_diff = -2 * (ko_y - y) / torch.sqrt((ko_x - x) ** 2 + (ko_y - y) ** 2)

    grad = torch.zeros((len(x), 2))
    grad[:, 0] = x_diff
    grad[:, 1] = y_diff

    return grad


def train_loop_gcbf(
    dataloader: DataLoader,
    model: Controller,
    loss_fn,
    optimizer: torch.optim.Optimizer,
    geo_constr_layer: CvxpyLayer,
    k1: torch.Tensor,
    k2: torch.Tensor,
    pool: Pool,
):
    model.train()

    batch_safe_loss = []
    batch_unsafe_loss = []
    for _batch, (p, x_traj, y_traj, u, ko) in enumerate(dataloader):
        # filters out all test cases where the current state is inside the
        # keep-out region (which would never occur in practice) as this
        # filtering operation cannot be done in the dataloader itself
        p_filt, x_traj_filt, y_traj_filt, u_filt, ko_filt = _filter_batch(
            p, x_traj, y_traj, u, ko
        )

        # CBF values
        h = _h_batch(p_filt, x_traj_filt, y_traj_filt, u_filt, ko_filt)
        h_grad = _h_grad(p_filt, x_traj_filt, y_traj_filt, u_filt, ko_filt)

        # makes a prediction on the control inputs which serves as the nominal
        # control input of the system
        pred_u = model(p_filt, x_traj_filt, y_traj_filt, h, h_grad)

        # uses the geometric safety layer to compute a safe input u
        safe_u = geo_constr_layer(
            pred_u,
            (pred_u, p_filt, ko_filt),  # batched arguments
            (k1, k2),  # non-batched arguments
            pool,  # for speed
        )

        # computes the loss between the filtered nominal controller and the
        # safe value of u (as computed through the CBF-QP)
        safe_loss = loss_fn(safe_u, u_filt)
        unsafe_loss = loss_fn(pred_u, u_filt)

        # backpropagation (through the optimization layer)
        safe_loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        batch_safe_loss.append(safe_loss.item())
        batch_unsafe_loss.append(unsafe_loss.item())

    # this will be our metric of performance
    avg_safe_batch_loss = sum(batch_safe_loss) / len(batch_safe_loss)
    avg_unsafe_batch_loss = sum(batch_unsafe_loss) / len(batch_unsafe_loss)
    return avg_safe_batch_loss, avg_unsafe_batch_loss


def valid_loop_gcbf(
    dataloader: DataLoader,
    model: Controller,
    loss_fn,
    geo_constr_layer: CvxpyLayer,
    k1: torch.Tensor,
    k2: torch.Tensor,
    pool: Pool,
):
    model.eval()

    batch_safe_loss = []
    batch_unsafe_loss = []
    for _batch, (p, x_traj, y_traj, u, ko) in enumerate(dataloader):
        # filters out all test cases where the current state is inside the
        # keep-out region (which would never occur in practice) as this
        # filtering operation cannot be done in the dataloader itself
        p_filt, x_traj_filt, y_traj_filt, u_filt, ko_filt = _filter_batch(
            p, x_traj, y_traj, u, ko
        )

        # CBF values
        h = _h_batch(p_filt, x_traj_filt, y_traj_filt, u_filt, ko_filt)
        h_grad = _h_grad(p_filt, x_traj_filt, y_traj_filt, u_filt, ko_filt)

        # makes a prediction on the control inputs which serves as the nominal
        # control input of the system
        pred_u = model(p_filt, x_traj_filt, y_traj_filt, h, h_grad)

        # uses the geometric safety layer to compute a safe input u
        safe_u = geo_constr_layer(
            pred_u,
            (pred_u, p_filt, ko_filt),  # batched arguments
            (k1, k2),  # non-batched arguments
            pool,  # for speed
        )

        # computes the loss between the filtered nominal controller and the
        # safe value of u (as computed through the CBF-QP)+
        safe_loss = loss_fn(safe_u, u_filt)
        unsafe_loss = loss_fn(pred_u, u_filt)

        batch_safe_loss.append(safe_loss.item())
        batch_unsafe_loss.append(unsafe_loss.item())

    # this will be our metric of performance
    avg_safe_batch_loss = sum(batch_safe_loss) / len(batch_safe_loss)
    avg_unsafe_batch_loss = sum(batch_unsafe_loss) / len(batch_unsafe_loss)
    return avg_safe_batch_loss, avg_unsafe_batch_loss

# %%
# controller params
state_dim = 5  # num states of dynamic unicycle
control_dim = 2  # num of inputs
traj_dim = 2  # only feeding in the trajectory position (not vel., accel.)

num_hidden_1 = 60
num_hidden_2 = 60

cntrllr_model = Controller(
    state_dim=state_dim,
    control_dim=control_dim,
    traj_dim=traj_dim,
    num_hidden_1=num_hidden_1,
    num_hidden_2=num_hidden_2,
    has_cbfs=True,
).to(device)

cntrllr_model
# Out:
# Controller(
#   (cntrllr): Sequential(
#     (0): Linear(in_features=10, out_features=60, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=60, out_features=60, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=60, out_features=2, bias=True)
#   )
# )

# %%
# hyperparameters
epochs = 100
batch_size = 128
lr = 0.001

mpc_train_loader = DataLoader(mpc_train_dataset, batch_size=batch_size, shuffle=True)
mpc_valid_loader = DataLoader(mpc_valid_dataset, batch_size=batch_size, shuffle=True)

# cbf params
k1 = 0.1
k2 = 0.05

# optimization params

constr_solv_cfg.penalty = 1000.0  # must be greater than 1 to grow
constr_solv_cfg.penalty_growth = 1.1  # must be greater than 1
constr_solv_cfg.ratio = 0.2
constr_solv_cfg.max_iters = 5000
constr_solv_cfg.conv_eps = 1e-3  # this is ignored by constrained solver control
constr_solv_cfg.g_mult_clips = (-10, 10)
constr_solv_cfg.h_mult_clips = (-10, 10)

# subsolver_cfg.conv_eps = 1e-3
subsolver_cfg.damp = 0.4
subsolver_cfg.damp_growth = 0.90
subsolver_cfg.max_iters = 5000
subsolver_cfg.damp_clip = [0.05, 1.0]

constr_solv_cfg.subsolver_acc_min = 1e-2
constr_solv_cfg.subsolver_acc = 1e-1  # starting
constr_solv_cfg.subsolver_acc_growth = 0.7


loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(params=cntrllr_model.parameters(), lr=lr)

# train the model

pbar = tqdm.tqdm(range(epochs), desc="Training")

# loss training history
safe_train_loss_hist = []
unsafe_train_loss_hist = []

safe_valid_loss_hist = []
unsafe_valid_loss_hist = []

# as we're passing batches to an optimization problem (that's unfortunately
# entirely written in Python) then for speed we need to create a
# multiprocessing context to use as many cores as possible

num_processes = 28
with Pool(processes=num_processes) as pool:
    for epoch in pbar:
        safe_train_loss, unsafe_train_loss = train_loop_gcbf(
            mpc_train_loader,
            cntrllr_model,
            loss_fn,
            optimizer,
            geo_constr_layer,
            k1,
            k2,
            None, # pool,
        )
        safe_valid_loss, unsafe_valid_loss = valid_loop_gcbf(
            mpc_valid_loader, cntrllr_model, loss_fn, geo_constr_layer, k1, k2, None, # pool
        )
        pbar.set_postfix(
            safe_train_loss=safe_train_loss,
            unsafe_train_loss=unsafe_train_loss,
            safe_valid_loss=safe_valid_loss,
            unsafe_valid_loss=unsafe_valid_loss,
        )

        safe_train_loss_hist.append(safe_train_loss)
        unsafe_train_loss_hist.append(unsafe_train_loss)

        safe_valid_loss_hist.append(safe_valid_loss)
        unsafe_valid_loss_hist.append(unsafe_valid_loss)

        print("Completed a full loop!")
# Out:
# Training:   0%|                                                             | 0/100 [00:00<?, ?it/s]
# Starting pool run!
# /home/samuel/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/diff_mfld_optim/geodesic/geodesic_funcs.py:58: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   raw_data = np.array(unwrapped_tensor.storage().tolist()[:total_len])
# Training:   0%|                                                             | 0/100 [01:22<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 55
#      53 with Pool(processes=num_processes) as pool:
#      54     for epoch in pbar:
# ---> 55         safe_train_loss, unsafe_train_loss = train_loop_gcbf(
#      56             mpc_train_loader,
#      57             cntrllr_model,
#      58             loss_fn,
#      59             optimizer,
#      60             geo_constr_layer,
#      61             k1,
#      62             k2,
#      63             None, # pool,
#      64         )
#      65         safe_valid_loss, unsafe_valid_loss = valid_loop_gcbf(
#      66             mpc_valid_loader, cntrllr_model, loss_fn, geo_constr_layer, k1, k2, None, # pool
#      67         )
#      68         pbar.set_postfix(
#      69             safe_train_loss=safe_train_loss,
#      70             unsafe_train_loss=unsafe_train_loss,
#      71             safe_valid_loss=safe_valid_loss,
#      72             unsafe_valid_loss=unsafe_valid_loss,
#      73         )
#
# Cell In[6], line 77, in train_loop_gcbf(dataloader, model, loss_fn, optimizer, geo_constr_layer, k1, k2, pool)
#      74 pred_u = model(p_filt, x_traj_filt, y_traj_filt, h, h_grad)
#      76 # uses the geometric safety layer to compute a safe input u
# ---> 77 safe_u = geo_constr_layer(
#      78     pred_u,
#      79     (pred_u, p_filt, ko_filt),  # batched arguments
#      80     (k1, k2),  # non-batched arguments
#      81     pool,  # for speed
#      82 )
#      84 # computes the loss between the filtered nominal controller and the
#      85 # safe value of u (as computed through the CBF-QP)
#      86 safe_loss = loss_fn(safe_u, u_filt)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/diff_mfld_optim/layers/diff_opt_layer.py:191, in DiffMfldOptimLayer.forward(self, p0, batched_args, args, pool)
#     189 if pool is None:
#     190     for i in range(num_batches):
# --> 191         p_optimal_batched[i, :] = DiffMfldOptimProblem.apply(
#     192             p0[i, :],
#     193             self.f,
#     194             self.gs,
#     195             self.hs,
#     196             self.mfld_cfg,
#     197             self.solve_cfg,
#     198             self.method,
#     199             *[arg[i, :] for arg in batched_args],
#     200             *args,
#     201         )
#     202 else:
#     203     # solves the optimization problem for all the batches included in
#     204     # the inputs using the multiprocessing pool for maximum speed (but
#     205     # we can't direclty apply the custom torch function this way as the
#     206     # autograd compute graph construction cannot cross processing
#     207     # bounds so we run the computation separately)
#     209     results: List[ConstrainedSolverResult] = list(
#     210         tqdm(pool.map(
#     211             lambda args: self.method(*args),
#    (...)    225         ))
#     226     )
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/torch/autograd/function.py:583, in Function.apply(cls, *args, **kwargs)
#     580 if not torch._C._are_functorch_transforms_active():
#     581     # See NOTE: [functorch vjp and autograd interaction]
#     582     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 583     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     585 if not is_setup_ctx_defined:
#     586     raise RuntimeError(
#     587         "In order to use an autograd.Function with functorch transforms "
#     588         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     589         "staticmethod. For more details, please see "
#     590         "https://pytorch.org/docs/main/notes/extending.func.html"
#     591     )
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/diff_mfld_optim/layers/diff_opt_layer.py:48, in DiffMfldOptimProblem.forward(ctx, p0, f, gs, hs, mfld_cfg, solve_cfg, method, *func_args)
#      46     result = p0
#      47 else:
# ---> 48     result: ConstrainedSolverResult = method(
#      49         f, gs, hs, p0, mfld_cfg, solve_cfg, *func_args
#      50     )
#      51 if not result.success:
#      52     raise ValueError(
#      53         "Differentiable manifold optimization layer failed to "
#      54         f"converge to a solution: {result}"
#      55     )
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/diff_mfld_optim/optim/constrained.py:118, in ralm(f, gs, hs, p0, mfld_cfg, solve_cfg, *args)
#     112 # print(f"Starting constrained!")
#     114 for i in range(solve_cfg.max_iters):
#     115     # finds the point that minimizes the augmented lagrangian function with
#     116     # with the current lagrangian multipliers
# --> 118     alf_result: SolverResult = solve_cfg.sub_method(
#     119         lambda p, mfld_cfg, *args: _ralm_subproblem(
#     120             p, solve_cfg.penalty, f, gs, hs, g_mults, h_mults, mfld_cfg, *args
#     121         ),
#     122         p,
#     123         mfld_cfg,
#     124         solve_cfg.sub_cfg,
#     125         *args,
#     126     )
#     127     p = alf_result.p
#     129     constr_violated, gs_eval, hs_eval = _constraints_violated(
#     130         p, gs, hs, mfld_cfg, solve_cfg.eq_eps, *args
#     131     )
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/diff_mfld_optim/optim/subsolver.py:58, in riem_grad_descent(f, p0, mfld_cfg, solv_cfg, *args)
#      51 solv_cfg = copy(solv_cfg)
#      53 for i in range(solv_cfg.max_iters):
#      54     # the jacobian takes too long so we abuse backward propagation here to
#      55     # compute the differential of f (the gradient according to torch is
#      56     # equivalent to differential in differential geometric terms)
# ---> 58     df = jacrev(lambda p: f(p, mfld_cfg, *args))(p)
#      60     # updates the point using the exponential map
#      61     grad_f = mfld_cfg.metric_field(p).sharp(df)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/torch/_functorch/eager_transforms.py:571, in jacrev.<locals>.wrapper_fn(*args)
#     568 @wraps(func)
#     569 def wrapper_fn(*args):
#     570     error_if_complex("jacrev", args, is_input=True)
# --> 571     vjp_out = _vjp_with_argnums(func, *args, argnums=argnums, has_aux=has_aux)
#     572     if has_aux:
#     573         output, vjp_fn, aux = vjp_out
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/torch/_functorch/vmap.py:48, in doesnt_support_saved_tensors_hooks.<locals>.fn(*args, **kwargs)
#      45 @functools.wraps(f)
#      46 def fn(*args, **kwargs):
#      47     with torch.autograd.graph.disable_saved_tensors_hooks(message):
# ---> 48         return f(*args, **kwargs)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/torch/_functorch/eager_transforms.py:359, in _vjp_with_argnums(func, argnums, has_aux, *primals)
#     357     diff_primals = _slice_argnums(primals, argnums, as_tuple=False)
#     358     tree_map_(partial(_create_differentiable, level=level), diff_primals)
# --> 359 primals_out = func(*primals)
#     361 if has_aux:
#     362     if not (isinstance(primals_out, tuple) and len(primals_out) == 2):
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/diff_mfld_optim/optim/subsolver.py:58, in riem_grad_descent.<locals>.<lambda>(p)
#      51 solv_cfg = copy(solv_cfg)
#      53 for i in range(solv_cfg.max_iters):
#      54     # the jacobian takes too long so we abuse backward propagation here to
#      55     # compute the differential of f (the gradient according to torch is
#      56     # equivalent to differential in differential geometric terms)
# ---> 58     df = jacrev(lambda p: f(p, mfld_cfg, *args))(p)
#      60     # updates the point using the exponential map
#      61     grad_f = mfld_cfg.metric_field(p).sharp(df)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/diff_mfld_optim/optim/constrained.py:119, in ralm.<locals>.<lambda>(p, mfld_cfg, *args)
#     112 # print(f"Starting constrained!")
#     114 for i in range(solve_cfg.max_iters):
#     115     # finds the point that minimizes the augmented lagrangian function with
#     116     # with the current lagrangian multipliers
#     118     alf_result: SolverResult = solve_cfg.sub_method(
# --> 119         lambda p, mfld_cfg, *args: _ralm_subproblem(
#     120             p, solve_cfg.penalty, f, gs, hs, g_mults, h_mults, mfld_cfg, *args
#     121         ),
#     122         p,
#     123         mfld_cfg,
#     124         solve_cfg.sub_cfg,
#     125         *args,
#     126     )
#     127     p = alf_result.p
#     129     constr_violated, gs_eval, hs_eval = _constraints_violated(
#     130         p, gs, hs, mfld_cfg, solve_cfg.eq_eps, *args
#     131     )
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/diff_mfld_optim/optim/constrained.py:72, in _ralm_subproblem(p, rho, f, gs, hs, mu_mults, lambda_mults, mfld_cfg, *args)
#      69 for j in range(len(hs)):
#      70     sum += (hs[j](p, mfld_cfg, *args) + lambda_mults[j] / rho) ** 2
# ---> 72 return f(p, mfld_cfg, *args) + rho / 2 * sum
#
# Cell In[5], line 5, in gcbf_f(u, mfld_cfg, u_nom, *_args)
#       4 def gcbf_f(u: torch.Tensor, mfld_cfg: MfldCfg, u_nom: torch.Tensor, *_args):
# ----> 5     return 0.5 * dist_squared_map(u, u_nom, mfld_cfg)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/diff_mfld_optim/mfld_util.py:30, in dist_squared_map(p, q, cfg)
#      28 def dist_squared_map(p, q, cfg: MfldCfg) -> torch.tensor:
#      29     # allows clean mfldcfg interface for use in cost and constraint functions
# ---> 30     return geodesic_funcs.dist_squared_map(
#      31         p, q, cfg.metric_field, cfg.conn, cfg.dist_method
#      32     )
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/diff_mfld_optim/geodesic/geodesic_funcs.py:251, in dist_squared_map(p, q, metric, conn, log_method)
#     249 if conn is None:
#     250     conn = metric.christoffels()
# --> 251 return DistSquaredMap.apply(p, q, metric, conn, log_method)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/torch/autograd/function.py:593, in Function.apply(cls, *args, **kwargs)
#     585 if not is_setup_ctx_defined:
#     586     raise RuntimeError(
#     587         "In order to use an autograd.Function with functorch transforms "
#     588         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     589         "staticmethod. For more details, please see "
#     590         "https://pytorch.org/docs/main/notes/extending.func.html"
#     591     )
# --> 593 return custom_function_call(cls, *args, **kwargs)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/torch/_functorch/autograd_function.py:49, in CustomFunctionHigherOrderOperator.__call__(self, autograd_function, *args, **kwargs)
#      36 def __call__(self, autograd_function, *args, **kwargs):
#      37     # When custom_function_call is done dispatching through functorch,
#      38     # it should just invoke the autograd.Function. This is consistent
#    (...)     46     # (because autograd.Function happens before the Python dispatch key)
#      47     # and only traces the forward pass.
#      48     if torch._C._are_functorch_transforms_active():
# ---> 49         return super().__call__(autograd_function, *args, **kwargs)
#      50     return autograd_function.apply(*args, **kwargs)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/torch/_ops.py:510, in HigherOrderOperator.__call__(self, *args, **kwargs)
#     505     return torch.overrides.handle_torch_function(
#     506         self, flat_args, *args, **kwargs
#     507     )
#     509 dispatch_key_set = _compute_keyset(args, kwargs, self.non_fallthrough_keys)
# --> 510 return self.dispatch(dispatch_key_set.highestPriorityTypeId(), *args, **kwargs)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/torch/_ops.py:363, in HigherOrderOperator.dispatch(self, dispatch_key, *args, **kwargs)
#     360     return kernel(*args, **kwargs)
#     362 if dispatch_key == DispatchKey.FuncTorchDynamicLayerFrontMode:
# --> 363     return dispatch_functorch(self, args, kwargs)
#     365 if dispatch_key == DispatchKey.Python:
#     366     # Keep the following 1:1 with handle_torch_function_no_python_arg_parser
#     367     # in torch/csrc/utils/python_arg_parser.cpp
#     369     overloaded_args_list = []
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/torch/_functorch/pyfunctorch.py:316, in dispatch_functorch(op, args, kwargs)
#     308 # In traditional PyTorch operators, DispatchKey::FuncTorchTensorWrapper's
#     309 # unwrap_dead_tensors fallback handles unwrapping dead tensor wrappers.
#     310 # PyDispatcher sidesteps the PyTorch dispatcher when dealing with functorch
#     311 # transforms, so we manually unwrap the dead tensors here.
#     312 # This logic won't need to exist when we have mode-only functorch.
#     313 args, kwargs = pytree.tree_map_only(
#     314     torch.Tensor, torch._C._functorch.unwrap_if_dead, (args, kwargs)
#     315 )
# --> 316 return interpreter.process(op, args, kwargs)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/torch/_functorch/pyfunctorch.py:187, in GradInterpreter.process(self, op, args, kwargs)
#     185 kernel = op.functorch_table[TransformType.Grad]
#     186 args, kwargs = self.lift(args, kwargs)
# --> 187 return kernel(self, *args, **kwargs)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/torch/_functorch/autograd_function.py:93, in custom_function_call_grad(interpreter, autograd_function, *operands)
#      91 Generated = generate_single_level_function(interpreter, autograd_function)
#      92 with enable_single_level_autograd_function():
# ---> 93     flat_out = Generated.apply(*operands)
#      94 return flat_out
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/torch/_functorch/autograd_function.py:121, in generate_single_level_function.<locals>.setup_context(ctx, inputs, output)
#     120 def setup_context(ctx, inputs, output):
# --> 121     return autograd_function.setup_context(ctx, inputs, output)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/diff_mfld_optim/geodesic/geodesic_funcs.py:162, in DistSquaredMap.setup_context(ctx, inputs, output)
#     159     conn = metric.christoffels()
#     161 g = metric(p)
# --> 162 v = log_method(p, q, conn)  # tangent space at p
#     164 dv = g.flat(v)  # cotangent space at p (differential)
#     165 diff_dist_sqr = -2 * dv
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/diff_mfld_optim/geodesic/geodesic_funcs.py:98, in LogMethod.__call__(self, p, q, conn)
#      97 def __call__(self, p: torch.tensor, q: torch.tensor, conn: Connection):
# ---> 98     return self.value(p, q, conn)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/diff_mfld_optim/geodesic/geodesic_funcs.py:79, in _LogMapWrapper.__call__(self, p, q, conn)
#      78 def __call__(self, p: torch.tensor, q: torch.tensor, conn: Connection):
# ---> 79     conn_coeffs = conn(p)
#      81     v = self._log_map(detach_numpy(p), detach_numpy(q), detach_numpy(conn_coeffs))
#      82     return torch.tensor(v, dtype=p.dtype, requires_grad=True)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/diff_mfld_optim/geometry/connection.py:32, in Connection.__call__(self, *coords_sets)
#      26 if coords_n != self.n:
#      27     raise ValueError(
#      28         "Coordinates passed to connection does not match dimension of "
#      29         f"underlying manifold: n={self.n}, coords_n={coords_n}"
#      30     )
# ---> 32 return self._eval(p)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/diff_mfld_optim/geometry/metric.py:20, in LeviCivitaConnection._eval(self, p)
#      19 def _eval(self, p):
# ---> 20     return self.fn(p)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/torch/_dynamo/eval_frame.py:953, in _TorchDynamoContext.__call__.<locals>.compile_wrapper(*args, **kwargs)
#     950 _maybe_set_eval_frame(_callback_from_stance(callback))
#     952 try:
# --> 953     return fn(*args, **kwargs)
#     954 except Unsupported as e:
#     955     if config.verbose:
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/diff_mfld_optim/geometry/metric.py:69, in MetricField.christoffels.<locals>.<lambda>(p)
#      63 g_mat_fn = lambda p: self.fn(*_coords(p))
#      64 g_inv_mat_fn = lambda p: torch.inverse(g_mat_fn(p))
#      66 return LeviCivitaConnection(
#      67     self.n,
#      68     torch.compile(
# ---> 69         lambda p: _eval_christoffels(self.n, g_mat_fn, g_inv_mat_fn, p),
#      70     ),
#      71 )
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/diff_mfld_optim/geometry/metric.py:32, in _eval_christoffels(n, g_fn, g_inv_fn, p)
#      30     coeff = 0.0
#      31     for m in range(n):
# ---> 32         coeff += (
#      33             0.5
#      34             * g_inv[k, m]
#      35             * (
#      36                 metric_partials[m, i, j]
#      37                 + metric_partials[m, j, i]
#      38                 - metric_partials[i, j, m]
#      39             )
#      40         )
#      41     conn_coeffs[k, i, j] = coeff
#      42 return conn_coeffs
#
# KeyboardInterrupt:

# %%
safe_train_loss_hist = np.asarray(safe_train_loss_hist)
unsafe_train_loss_hist = np.asarray(unsafe_train_loss_hist)

safe_valid_loss_hist = np.asarray(safe_valid_loss_hist)
unsafe_valid_loss_hist = np.asarray(unsafe_valid_loss_hist)

fig, (ax1, ax2) = plt.subplots(2, 1)
# plt.plot(safe_train_loss_hist)

ax1.plot(safe_train_loss_hist)
ax1.plot(safe_valid_loss_hist)

ax2.plot(unsafe_train_loss_hist)
ax2.plot(unsafe_valid_loss_hist)

# %%
# save the model with a unique timestamp (to prevent overwriting models)

output_dir = pathlib.Path("nn_with_gcbf_layer")
timestamp = datetime.now().strftime("%Y_%m_%d__%H_%M")

model_path = output_dir.joinpath(f"model_{timestamp}.pth")
torch.save(cntrllr_model.state_dict(), model_path)

np.save(output_dir.joinpath(f"safe_train_loss_hist_{timestamp}"), safe_train_loss_hist)
np.save(
    output_dir.joinpath(f"unsafe_train_loss_hist_{timestamp}"), unsafe_train_loss_hist
)
np.save(output_dir.joinpath(f"safe_valid_loss_hist_{timestamp}"), safe_valid_loss_hist)
np.save(
    output_dir.joinpath(f"unsafe_valid_loss_hist_{timestamp}"), unsafe_valid_loss_hist
)

# %%
import sympy as sp
import sympy.diffgeom as dg

# %%
state_mfld = dg.Manifold("M", 5)
state_mfld_patch = dg.Patch("P", state_mfld)

x, y, theta, v, omega = sp.symbols(r"x,y,\theta,v,\omega", real=True)

state_mfld_coords = dg.CoordSystem(
    "StateSpace", state_mfld_patch, (x, y, theta, v, omega)
)

(x_sc, y_sc, theta_sc, v_sc, omega_sc) = state_mfld_coords.base_scalars()
(x_vec, y_vec, theta_vec, v_vec, omega_vec) = state_mfld_coords.base_vectors()

# %%
# define the vector fields of the system

f = (
    v_sc * sp.cos(theta_sc) * x_vec
    + v_sc * sp.sin(theta_sc) * y_vec
    + omega_sc * theta_vec
)

f1 = v_vec
f2 = omega_vec

u_f, u_t = sp.symbols("u_f,u_t", real=True)

display(f, f1, f2)
display(u_f, u_t)
# Out:
# sin(\theta)*v*e_y + cos(\theta)*v*e_x + \omega*e_\theta
# e_v
# e_\omega
# u_f
# u_t

# %%
# define the variables associated with the keep out region
t = sp.symbols("t", real=True)

x_ko = sp.Function("x_ko")(t)
y_ko = sp.Function("y_ko")(t)
r_ko = sp.Function("r_ko")(t)

ko_cbf = sp.sqrt((x_sc - x_ko) ** 2 + (y_sc - y_ko) ** 2) - r_ko
display(ko_cbf)
# Out:
# sqrt((-x_ko(t) + x)**2 + (-y_ko(t) + y)**2) - r_ko(t)

# %%
# generates the condition for the HOCBF


def _repeated_lie_deriv(f, h, n):
    if n == 0:
        return h
    return _repeated_lie_deriv(f, dg.LieDerivative(f, h), n - 1)


def gen_hocbf_condition(dyn_f, dyn_gs, us, m, h, t, alpha_fns):
    lie_m_fh = _repeated_lie_deriv(dyn_f, h, m)
    lie_g_fh = sum(
        dg.LieDerivative(g, _repeated_lie_deriv(f, h, m - 1)) * u
        for (g, u) in zip(dyn_gs, us)
    )
    dmh_dtm = sp.diff(h, t, m)

    alpha_fns.insert(0, lambda phi: 1.0 * phi)  # dummy to ensure correct indexing

    phi_fns = [h]
    for i in range(1, m):
        phi_fns.append(sp.diff(phi_fns[i - 1], t) + alpha_fns[i](phi_fns[i - 1]))

    o_h = 0
    for i in range(1, m - 1):
        # same thing here with the alpha indexing
        alpha_phi_fn = alpha_fns[m - i](phi_fns[m - i - 1])
        o_h += _repeated_lie_deriv(f, alpha_phi_fn, i) + sp.diff(alpha_phi_fn, t, i)

    final_alpha_phi = alpha_fns[m](phi_fns[m - 1])

    return lie_m_fh + lie_g_fh + dmh_dtm + o_h + final_alpha_phi


# assuming the use of linear extended K_infty functions
k1, k2 = sp.symbols("k1,k2", nonneg=True, real=True)

ko_hocbf = (
    gen_hocbf_condition(
        f, [f1, f2], [u_f, u_t], 2, ko_cbf, t, [lambda x: k1 * x, lambda x: k2 * x]
    )
    .nsimplify()
    .simplify()
)

display(ko_hocbf)  # ouch
# Out:
# (-((((x_ko(t) - x)*cos(\theta) + (y_ko(t) - y)*sin(\theta))*(x_ko(t) - x) - ((x_ko(t) - x)**2 + (y_ko(t) - y)**2)*cos(\theta))*cos(\theta) + (((x_ko(t) - x)*cos(\theta) + (y_ko(t) - y)*sin(\theta))*(y_ko(t) - y) - ((x_ko(t) - x)**2 + (y_ko(t) - y)**2)*sin(\theta))*sin(\theta))*((x_ko(t) - x)**2 + (y_ko(t) - y)**2)**(5/2)*v**2 - ((x_ko(t) - x)*Derivative(x_ko(t), t) + (y_ko(t) - y)*Derivative(y_ko(t), t))**2*((x_ko(t) - x)**2 + (y_ko(t) - y)**2)**(5/2) + ((x_ko(t) - x)**2 + (y_ko(t) - y)**2)**(7/2)*(-k2*((-k1*(sqrt((x_ko(t) - x)**2 + (y_ko(t) - y)**2) - r_ko(t)) + Derivative(r_ko(t), t))*sqrt((x_ko(t) - x)**2 + (y_ko(t) - y)**2) - (x_ko(t) - x)*Derivative(x_ko(t), t) - (y_ko(t) - y)*Derivative(y_ko(t), t)) - u_f*((x_ko(t) - x)*cos(\theta) + (y_ko(t) - y)*sin(\theta)) + ((x_ko(t) - x)*sin(\theta) + (-y_ko(t) + y)*cos(\theta))*v*\omega + (x_ko(t) - x)*Derivative(x_ko(t), (t, 2)) + (y_ko(t) - y)*Derivative(y_ko(t), (t, 2)) + Derivative(x_ko(t), t)**2 + Derivative(y_ko(t), t)**2) - ((x_ko(t) - x)**2 + (y_ko(t) - y)**2)**4*Derivative(r_ko(t), (t, 2)))/((x_ko(t) - x)**2 + (y_ko(t) - y)**2)**4

# %%
# devise some simplifications that might help

x_err_sym, y_err_sym, r_sqr_err_sym, r_1_sym, r_2_sym, r_3_sym, r_4_sym, r_5_sym = (
    sp.symbols("x_err,y_err,r^2_err,r_1,r_2,r_3,r_4,r_5", real=True)
)

x_err = x_ko - x_sc
y_err = y_ko - y_sc
r_sqr_err = x_err_sym**2 + y_err_sym**2

r_1 = r_sqr_err_sym ** (sp.Rational(7 / 2)) * x_err_sym
r_2 = r_sqr_err_sym ** (sp.Rational(7 / 2)) * y_err_sym
r_3 = r_sqr_err_sym ** (sp.Rational(5 / 2)) * x_err_sym**2
r_4 = r_sqr_err_sym ** (sp.Rational(5 / 2)) * y_err_sym**2
r_5 = r_sqr_err_sym ** (sp.Rational(5 / 2)) * x_err_sym * y_err_sym

ko_hocbf_cleaned = (
    (ko_hocbf.subs(x_err, x_err_sym).subs(y_err, y_err_sym).subs(r_sqr_err, r_sqr_err_sym))
    .simplify()
    .factor()
    .subs(r_1, r_1_sym)
    .subs(r_2, r_2_sym)
    .subs(r_3, r_3_sym)
    .subs(r_4, r_4_sym)
    .subs(r_5, r_5_sym)
).factor()
display(ko_hocbf_cleaned)
# Out:
# -(-2*k1*k2*r^2_err**(9/2) + 2*k1*k2*r^2_err**4*r_ko(t) + 2*k2*r^2_err**4*Derivative(r_ko(t), t) - 2*k2*r_1*Derivative(x_ko(t), t) - 2*k2*r_2*Derivative(y_ko(t), t) - 2*r^2_err**(7/2)*v**2 - 2*r^2_err**(7/2)*Derivative(x_ko(t), t)**2 - 2*r^2_err**(7/2)*Derivative(y_ko(t), t)**2 + 2*r^2_err**4*Derivative(r_ko(t), (t, 2)) + 2*r_1*u_f*cos(\theta) - 2*r_1*sin(\theta)*v*\omega - 2*r_1*Derivative(x_ko(t), (t, 2)) + 2*r_2*u_f*sin(\theta) + 2*r_2*cos(\theta)*v*\omega - 2*r_2*Derivative(y_ko(t), (t, 2)) + r_3*cos(2*\theta)*v**2 + r_3*v**2 + 2*r_3*Derivative(x_ko(t), t)**2 - r_4*cos(2*\theta)*v**2 + r_4*v**2 + 2*r_4*Derivative(y_ko(t), t)**2 + 2*r_5*sin(2*\theta)*v**2 + 4*r_5*Derivative(x_ko(t), t)*Derivative(y_ko(t), t))/(2*r^2_err**4)

# %%
# final HOCBF (to use as condition in optimization problem)
ko_hocbf_condition = ko_hocbf_cleaned >= 0
display(ko_hocbf_condition)

display(sp.Eq(x_err_sym, x_err))
display(sp.Eq(y_err_sym, y_err))
display(sp.Eq(r_sqr_err_sym, r_sqr_err))
display(sp.Eq(r_1_sym, r_1))
display(sp.Eq(r_2_sym, r_2))
display(sp.Eq(r_3_sym, r_3))
display(sp.Eq(r_4_sym, r_4))
display(sp.Eq(r_5_sym, r_5))

sp.print_latex(ko_hocbf_condition)

# %% [markdown]
# The following computes the gradient and part of the covariant hessian necessary for implementation of the GHOCBF in the product manifold formulation.

# %%
ko_hocbf

# %%
# replace the scalar functions in the expression with the symbols so we can evaluate regular derivatives for
# the gradient and the necessary part of the covariant hessian
ko_hocbf_symbs = ko_hocbf.subs(x_sc, x).subs(y_sc, y).subs(theta_sc, theta).subs(v_sc, v).subs(omega_sc, omega)
ko_hocbf_symbs

# %%
prod_mfld_coords = sp.Matrix([x, y, theta, v, omega, u_f, u_t])
prod_mfld_coords

# %%
ko_hocbf_symbs_grad = sp.Matrix([ko_hocbf_symbs]).jacobian(prod_mfld_coords).simplify()
ko_hocbf_symbs_grad.T
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 ko_hocbf_symbs_grad = sp.Matrix([ko_hocbf_symbs]).jacobian(prod_mfld_coords).simplify()
#       2 ko_hocbf_symbs_grad.T
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/matrices/dense.py:129, in MutableDenseMatrix.simplify(self, **kwargs)
#     127 from sympy.simplify.simplify import simplify as _simplify
#     128 for (i, j), element in self.todok().items():
# --> 129     self[i, j] = _simplify(element, **kwargs)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/simplify/simplify.py:713, in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     710     expr = besselsimp(expr)
#     712 if expr.has(TrigonometricFunction, HyperbolicFunction):
# --> 713     expr = trigsimp(expr, deep=True)
#     715 if expr.has(log):
#     716     expr = shorter(expand_log(expr, deep=True), logcombine(expr))
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/simplify/trigsimp.py:564, in trigsimp(expr, inverse, **opts)
#     553     return trigsimp_groebner(new, **opts)
#     555 trigsimpfunc = {
#     556     'fu': (lambda x: fu(x, **opts)),
#     557     'matching': (lambda x: futrig(x)),
#    (...)    561     'old': lambda x: trigsimp_old(x, **opts),
#     562                }[method]
# --> 564 expr_simplified = trigsimpfunc(expr)
#     565 if inverse:
#     566     expr_simplified = _trigsimp_inverse(expr_simplified)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/simplify/trigsimp.py:557, in trigsimp.<locals>.<lambda>(x)
#     552         return new
#     553     return trigsimp_groebner(new, **opts)
#     555 trigsimpfunc = {
#     556     'fu': (lambda x: fu(x, **opts)),
# --> 557     'matching': (lambda x: futrig(x)),
#     558     'groebner': (lambda x: groebnersimp(x, **opts)),
#     559     'combined': (lambda x: futrig(groebnersimp(x,
#     560                            polynomial=True, hints=[2, tan]))),
#     561     'old': lambda x: trigsimp_old(x, **opts),
#     562                }[method]
#     564 expr_simplified = trigsimpfunc(expr)
#     565 if inverse:
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/simplify/trigsimp.py:1158, in futrig(e, hyper, **kwargs)
#    1155     return e
#    1157 old = e
# -> 1158 e = bottom_up(e, _futrig)
#    1160 if hyper and e.has(HyperbolicFunction):
#    1161     e, f = hyper_as_trig(e)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/core/traversal.py:234, in bottom_up(rv, F, atoms, nonbasic)
#     232 if args is not None:
#     233     if args:
# --> 234         args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#     235         if args != rv.args:
#     236             rv = rv.func(*args)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/core/traversal.py:234, in bottom_up(rv, F, atoms, nonbasic)
#     232 if args is not None:
#     233     if args:
# --> 234         args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#     235         if args != rv.args:
#     236             rv = rv.func(*args)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/core/traversal.py:234, in bottom_up(rv, F, atoms, nonbasic)
#     232 if args is not None:
#     233     if args:
# --> 234         args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#     235         if args != rv.args:
#     236             rv = rv.func(*args)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/core/traversal.py:237, in bottom_up(rv, F, atoms, nonbasic)
#     235     if args != rv.args:
#     236         rv = rv.func(*args)
# --> 237     rv = F(rv)
#     238 elif atoms:
#     239     rv = F(rv)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/simplify/trigsimp.py:1225, in _futrig(e)
#    1186 trigs = lambda x: x.has(TrigonometricFunction)
#    1188 tree = [identity,
#    1189     (
#    1190     TR3,  # canonical angles
#    (...)   1223         factor_terms, TR12(x), trigs)],  # expand tan of sum
#    1224     )]
# -> 1225 e = greedy(tree, objective=Lops)(e)
#    1227 if coeff is not None:
#    1228     e = coeff * e
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/strategies/core.py:150, in minimize.<locals>.minrule(expr)
#     149 def minrule(expr: _S) -> _T:
# --> 150     return min([rule(expr) for rule in rules], key=objective)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/strategies/core.py:64, in chain.<locals>.chain_rl(expr)
#      62 def chain_rl(expr: _T) -> _T:
#      63     for rule in rules:
# ---> 64         expr = rule(expr)
#      65     return expr
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/simplify/trigsimp.py:1193, in _futrig.<locals>.<lambda>(x)
#    1185 Lops = lambda x: (L(x), x.count_ops(), _nodes(x), len(x.args), x.is_Add)
#    1186 trigs = lambda x: x.has(TrigonometricFunction)
#    1188 tree = [identity,
#    1189     (
#    1190     TR3,  # canonical angles
#    1191     TR1,  # sec-csc -> cos-sin
#    1192     TR12,  # expand tan of sum
# -> 1193     lambda x: _eapply(factor, x, trigs),
#    1194     TR2,  # tan-cot -> sin-cos
#    1195     [identity, lambda x: _eapply(_mexpand, x, trigs)],
#    1196     TR2i,  # sin-cos ratio -> tan
#    1197     lambda x: _eapply(lambda i: factor(i.normal()), x, trigs),
#    1198     TR14,  # factored identities
#    1199     TR5,  # sin-pow -> cos_pow
#    1200     TR10,  # sin-cos of sums -> sin-cos prod
#    1201     TR11, _TR11, TR6, # reduce double angles and rewrite cos pows
#    1202     lambda x: _eapply(factor, x, trigs),
#    1203     TR14,  # factored powers of identities
#    1204     [identity, lambda x: _eapply(_mexpand, x, trigs)],
#    1205     TR10i,  # sin-cos products > sin-cos of sums
#    1206     TRmorrie,
#    1207     [identity, TR8],  # sin-cos products -> sin-cos of sums
#    1208     [identity, lambda x: TR2i(TR2(x))],  # tan -> sin-cos -> tan
#    1209     [
#    1210         lambda x: _eapply(expand_mul, TR5(x), trigs),
#    1211         lambda x: _eapply(
#    1212             expand_mul, TR15(x), trigs)], # pos/neg powers of sin
#    1213     [
#    1214         lambda x:  _eapply(expand_mul, TR6(x), trigs),
#    1215         lambda x:  _eapply(
#    1216             expand_mul, TR16(x), trigs)], # pos/neg powers of cos
#    1217     TR111,  # tan, sin, cos to neg power -> cot, csc, sec
#    1218     [identity, TR2i],  # sin-cos ratio to tan
#    1219     [identity, lambda x: _eapply(
#    1220         expand_mul, TR22(x), trigs)],  # tan-cot to sec-csc
#    1221     TR1, TR2, TR2i,
#    1222     [identity, lambda x: _eapply(
#    1223         factor_terms, TR12(x), trigs)],  # expand tan of sum
#    1224     )]
#    1225 e = greedy(tree, objective=Lops)(e)
#    1227 if coeff is not None:
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/simplify/trigsimp.py:1249, in _eapply(func, e, cond)
#    1247     return e
#    1248 if _is_Expr(e) or not e.args:
# -> 1249     return func(e)
#    1250 return e.func(*[
#    1251     _eapply(func, ei) if (cond is None or cond(ei)) else ei
#    1252     for ei in e.args])
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/polytools.py:6735, in factor(f, deep, *gens, **args)
#    6732     return f.xreplace(partials)
#    6734 try:
# -> 6735     return _generic_factor(f, gens, args, method='factor')
#    6736 except PolynomialError:
#    6737     if not f.is_commutative:
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/polytools.py:6416, in _generic_factor(expr, gens, args, method)
#    6414 opt = options.build_options(gens, args)
#    6415 opt['fraction'] = fraction
# -> 6416 return _symbolic_factor(sympify(expr), opt, method)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/polytools.py:6356, in _symbolic_factor(expr, opt, method)
#    6354     if hasattr(expr,'_eval_factor'):
#    6355         return expr._eval_factor()
# -> 6356     coeff, factors = _symbolic_factor_list(together(expr, fraction=opt['fraction']), opt, method)
#    6357     return _keep_coeff(coeff, _factors_product(factors))
#    6358 elif hasattr(expr, 'args'):
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/polytools.py:6318, in _symbolic_factor_list(expr, opt, method)
#    6315 else:
#    6316     func = getattr(poly, method + '_list')
# -> 6318     _coeff, _factors = func()
#    6319     if _coeff is not S.One:
#    6320         if exp.is_Integer:
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/polytools.py:3377, in Poly.factor_list(f)
#    3375 if hasattr(f.rep, 'factor_list'):
#    3376     try:
# -> 3377         coeff, factors = f.rep.factor_list()
#    3378     except DomainError:
#    3379         if f.degree() == 0:
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/polyclasses.py:1640, in DMP_Python.factor_list(f)
#    1638 def factor_list(f):
#    1639     """Returns a list of irreducible factors of ``f``. """
# -> 1640     coeff, factors = dmp_factor_list(f._rep, f.lev, f.dom)
#    1641     return coeff, [ (f.per(g), k) for g, k in factors ]
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/factortools.py:1569, in dmp_factor_list(f, u, K0)
#    1567 if K.is_ZZ:
#    1568     levels, f, v = dmp_exclude(f, u, K)
# -> 1569     coeff, factors = dmp_zz_factor(f, v, K)
#    1571     for i, (f, k) in enumerate(factors):
#    1572         factors[i] = (dmp_include(f, levels, v, K), k)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/factortools.py:1189, in dmp_zz_factor(f, u, K)
#    1187 if dmp_degree(g, u) > 0:
#    1188     g = dmp_sqf_part(g, u, K)
# -> 1189     H = dmp_zz_wang(g, u, K)
#    1190     factors = dmp_trial_division(f, H, u, K)
#    1192 for g, k in dmp_zz_factor(G, u - 1, K)[1]:
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/factortools.py:1112, in dmp_zz_wang(f, u, K, mod, seed)
#    1110 try:
#    1111     f, H, LC = dmp_zz_wang_lead_coeffs(f, T, cs, E, H, A, u, K)
# -> 1112     factors = dmp_zz_wang_hensel_lifting(f, H, LC, A, p, u, K)
#    1113 except ExtraneousFactors:  # pragma: no cover
#    1114     if query('EEZ_RESTART_IF_NEEDED'):
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/factortools.py:976, in dmp_zz_wang_hensel_lifting(f, H, LC, A, p, u, K)
#     974 if not dmp_zero_p(C, w - 1):
#     975     C = dmp_quo_ground(C, K.factorial(K(k) + 1), w - 1, K)
# --> 976     T = dmp_zz_diophantine(G, C, I, d, p, w - 1, K)
#     978     for i, (h, t) in enumerate(zip(H, T)):
#     979         h = dmp_add_mul(h, dmp_raise(t, 1, w - 1, K), M, w, K)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/factortools.py:901, in dmp_zz_diophantine(F, c, A, d, p, u, K)
#     897 C = dmp_eval_in(c, a, n, u, K)
#     899 v = u - 1
# --> 901 S = dmp_zz_diophantine(G, C, A, d, p, v, K)
#     902 S = [ dmp_raise(s, 1, v, K) for s in S ]
#     904 for s, b in zip(S, B):
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/factortools.py:901, in dmp_zz_diophantine(F, c, A, d, p, u, K)
#     897 C = dmp_eval_in(c, a, n, u, K)
#     899 v = u - 1
# --> 901 S = dmp_zz_diophantine(G, C, A, d, p, v, K)
#     902 S = [ dmp_raise(s, 1, v, K) for s in S ]
#     904 for s, b in zip(S, B):
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/factortools.py:921, in dmp_zz_diophantine(F, c, A, d, p, u, K)
#     919 if not dmp_zero_p(C, v):
#     920     C = dmp_quo_ground(C, K.factorial(K(k) + 1), v, K)
# --> 921     T = dmp_zz_diophantine(G, C, A, d, p, v, K)
#     923     for i, t in enumerate(T):
#     924         T[i] = dmp_mul(dmp_raise(t, 1, v, K), M, u, K)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/factortools.py:901, in dmp_zz_diophantine(F, c, A, d, p, u, K)
#     897 C = dmp_eval_in(c, a, n, u, K)
#     899 v = u - 1
# --> 901 S = dmp_zz_diophantine(G, C, A, d, p, v, K)
#     902 S = [ dmp_raise(s, 1, v, K) for s in S ]
#     904 for s, b in zip(S, B):
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/factortools.py:901, in dmp_zz_diophantine(F, c, A, d, p, u, K)
#     897 C = dmp_eval_in(c, a, n, u, K)
#     899 v = u - 1
# --> 901 S = dmp_zz_diophantine(G, C, A, d, p, v, K)
#     902 S = [ dmp_raise(s, 1, v, K) for s in S ]
#     904 for s, b in zip(S, B):
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/factortools.py:921, in dmp_zz_diophantine(F, c, A, d, p, u, K)
#     919 if not dmp_zero_p(C, v):
#     920     C = dmp_quo_ground(C, K.factorial(K(k) + 1), v, K)
# --> 921     T = dmp_zz_diophantine(G, C, A, d, p, v, K)
#     923     for i, t in enumerate(T):
#     924         T[i] = dmp_mul(dmp_raise(t, 1, v, K), M, u, K)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/factortools.py:921, in dmp_zz_diophantine(F, c, A, d, p, u, K)
#     919 if not dmp_zero_p(C, v):
#     920     C = dmp_quo_ground(C, K.factorial(K(k) + 1), v, K)
# --> 921     T = dmp_zz_diophantine(G, C, A, d, p, v, K)
#     923     for i, t in enumerate(T):
#     924         T[i] = dmp_mul(dmp_raise(t, 1, v, K), M, u, K)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/factortools.py:901, in dmp_zz_diophantine(F, c, A, d, p, u, K)
#     897 C = dmp_eval_in(c, a, n, u, K)
#     899 v = u - 1
# --> 901 S = dmp_zz_diophantine(G, C, A, d, p, v, K)
#     902 S = [ dmp_raise(s, 1, v, K) for s in S ]
#     904 for s, b in zip(S, B):
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/factortools.py:894, in dmp_zz_diophantine(F, c, A, d, p, u, K)
#     891 B, G = [], []
#     893 for f in F:
# --> 894     B.append(dmp_quo(e, f, u, K))
#     895     G.append(dmp_eval_in(f, a, n, u, K))
#     897 C = dmp_eval_in(c, a, n, u, K)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/densearith.py:1671, in dmp_quo(f, g, u, K)
#    1653 def dmp_quo(f, g, u, K):
#    1654     """
#    1655     Returns exact polynomial quotient in ``K[X]``.
#    1656
#    (...)   1669
#    1670     """
# -> 1671     return dmp_div(f, g, u, K)[0]
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/densearith.py:1629, in dmp_div(f, g, u, K)
#    1627     return dmp_ff_div(f, g, u, K)
#    1628 else:
# -> 1629     return dmp_rr_div(f, g, u, K)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/densearith.py:1389, in dmp_rr_div(f, g, u, K)
#    1387 while True:
#    1388     lc_r = dmp_LC(r, K)
# -> 1389     c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1391     if not dmp_zero_p(R, v):
#    1392         break
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/densearith.py:1389, in dmp_rr_div(f, g, u, K)
#    1387 while True:
#    1388     lc_r = dmp_LC(r, K)
# -> 1389     c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1391     if not dmp_zero_p(R, v):
#    1392         break
#
#     [... skipping similar frames: dmp_rr_div at line 1389 (2 times)]
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/densearith.py:1389, in dmp_rr_div(f, g, u, K)
#    1387 while True:
#    1388     lc_r = dmp_LC(r, K)
# -> 1389     c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1391     if not dmp_zero_p(R, v):
#    1392         break
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/densearith.py:1397, in dmp_rr_div(f, g, u, K)
#    1394 j = dr - dg
#    1396 q = dmp_add_term(q, c, j, u, K)
# -> 1397 h = dmp_mul_term(g, c, j, u, K)
#    1398 r = dmp_sub(r, h, u, K)
#    1400 _dr, dr = dr, dmp_degree(r, u)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/densearith.py:184, in dmp_mul_term(f, c, i, u, K)
#     182     return dmp_zero(u)
#     183 else:
# --> 184     return [ dmp_mul(cf, c, v, K) for cf in f ] + dmp_zeros(i, v, K)
#
# File ~/Documents/School/UWaterloo_MASc/Research_Activities/research-geo-diff-opt-layer/.venv/lib/python3.14t/site-packages/sympy/polys/densearith.py:827, in dmp_mul(f, g, u, K)
#     824 for i in range(0, df + dg + 1):
#     825     coeff = dmp_zero(v)
# --> 827     for j in range(max(0, i - dg), min(df, i) + 1):
#     828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#
# KeyboardInterrupt:
